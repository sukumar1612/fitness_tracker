# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/My Drive/dataset.csv")

# %%
df.drop(['username','wrist','gyro_x','gyro_y','gyro_z'],axis=1,inplace=True)

# %%
df
# Out:
#             date                time  ...  acceleration_y  acceleration_z
# 0      2017-6-30  13:51:15:847724020  ...         -0.7814         -0.0076
# 1      2017-6-30  13:51:16:246945023  ...         -1.1233         -0.2344
# 2      2017-6-30  13:51:16:446233987  ...         -1.4817          0.0722
# 3      2017-6-30  13:51:16:646117985  ...         -0.8125          0.0888
# 4      2017-6-30  13:51:16:846738994  ...         -0.9312          0.0359
# ...          ...                 ...  ...             ...             ...
# 88583   2017-7-9   20:9:15:317911028  ...         -0.8376         -0.1327
# 88584   2017-7-9   20:9:15:517889022  ...         -1.0027         -0.4397
# 88585   2017-7-9   20:9:15:717828989  ...         -1.1780         -0.2827
# 88586   2017-7-9   20:9:15:917932987  ...         -0.8582         -0.0759
# 88587   2017-7-9   20:9:16:117410004  ...         -0.8008         -0.0911
#
# [88588 rows x 6 columns]

# %%
df['activity'].values
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df[df['activity']==1]
# Out:
#             date                time  ...  acceleration_y  acceleration_z
# 755    2017-6-30  20:33:44:257565021  ...          0.0526         -0.2362
# 756    2017-6-30  20:33:44:457401990  ...          0.4504         -0.1000
# 757    2017-6-30  20:33:44:658038020  ...         -0.9857         -0.0732
# 758    2017-6-30  20:33:44:858160972  ...         -0.7203          0.2003
# 759    2017-6-30   20:33:45:57991981  ...          0.3441         -0.2760
# ...          ...                 ...  ...             ...             ...
# 87750   2017-7-9   20:6:14:916516005  ...         -0.8527         -1.1410
# 87751   2017-7-9   20:6:15:116733014  ...          0.6734         -0.2263
# 87752   2017-7-9   20:6:15:315971016  ...         -0.4055         -2.4827
# 87753   2017-7-9   20:6:15:515972971  ...         -0.3176          0.5294
# 87754   2017-7-9   20:6:15:716033995  ...         -1.5834         -2.7183
#
# [44365 rows x 6 columns]

# %%
df.iloc[700:755]
# Out:
#           date                time  ...  acceleration_y  acceleration_z
# 700  2017-6-30  13:55:27:879875004  ...         -1.2800         -0.2143
# 701  2017-6-30   13:55:36:96974015  ...         -0.6680         -0.1671
# 702  2017-6-30  13:55:36:296742975  ...         -0.9953         -0.1865
# 703  2017-6-30  13:55:36:496209979  ...         -0.7002         -0.1922
# 704  2017-6-30  13:55:36:696870982  ...         -1.1446         -0.2964
# 705  2017-6-30  13:55:36:895990014  ...         -1.1576         -0.1143
# 706  2017-6-30   13:55:37:97315013  ...         -0.7670         -0.0124
# 707  2017-6-30  13:55:37:297173023  ...         -1.0885         -0.1022
# 708  2017-6-30  13:55:37:496837019  ...         -0.8454         -0.1413
# 709  2017-6-30  13:55:37:696981012  ...         -0.8421         -0.2732
# 710  2017-6-30  13:55:37:896121025  ...         -1.1694         -0.2771
# 711  2017-6-30   13:55:38:96381008  ...         -0.7514         -0.0474
# ...

# %%
df.iloc[0]
# Out:
# date                       2017-6-30
# time              13:51:15:847724020
# activity                           0
# acceleration_x                 0.265
# acceleration_y               -0.7814
# acceleration_z               -0.0076
# Name: 0, dtype: object

# %%
df.describe()
# Out:
#            activity  acceleration_x  acceleration_y  acceleration_z
# count  88588.000000    88588.000000    88588.000000    88588.000000
# mean       0.500801       -0.074811       -0.562585       -0.313956
# std        0.500002        1.009299        0.658458        0.486815
# min        0.000000       -5.350500       -3.299000       -3.753800
# 25%        0.000000       -0.381800       -1.033500       -0.376000
# 50%        1.000000       -0.059500       -0.759100       -0.221000
# 75%        1.000000        0.355500       -0.241775       -0.085900
# max        1.000000        5.603300        2.668000        1.640300

# %%
df1=df.loc[::200,'acceleration_x']
df2=df.loc[::200,'time']

# %%
df.count()
# Out:
# date              88588
# time              88588
# activity          88588
# acceleration_x    88588
# acceleration_y    88588
# acceleration_z    88588
# dtype: int64

# %%
df1
# Out:
# 0        0.2650
# 200      0.3225
# 400      0.3070
# 600      0.6054
# 800      1.0764
#           ...
# 87600    0.4192
# 87800    0.2755
# 88000    0.3834
# 88200    0.5513
# 88400    0.4098
# Name: acceleration_x, Length: 443, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(df2,df1)
plt.show()

# %%
df1=df.loc[::200,'acceleration_y']
df2=df.loc[::200,'time']

# %%
plt.plot(df2,df1)
plt.show()

# %%
df1=df.loc[::200,'acceleration_z']
df2=df.loc[::200,'time']
plt.plot(df2,df1)
plt.show()

# %%
df["total_acc"]=np.sqrt((df["acceleration_x"]**2)+(df["acceleration_y"]**2)+(df["acceleration_z"]**2))

# %%
X=df[['acceleration_x','acceleration_y','acceleration_z','total_acc']]

# %%
y=df['activity']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95     17683
#            1       0.97      0.92      0.94     17753
#
#     accuracy                           0.94     35436
#    macro avg       0.95      0.94      0.94     35436
# weighted avg       0.95      0.94      0.94     35436

# %%
model.score(X_test,y_test)
# Out:
# 0.9442657184783836

# %%
df
# Out:
#             date                time  ...  acceleration_z  total_acc
# 0      2017-6-30  13:51:15:847724020  ...         -0.0076   0.825148
# 1      2017-6-30  13:51:16:246945023  ...         -0.2344   1.329887
# 2      2017-6-30  13:51:16:446233987  ...          0.0722   1.547307
# 3      2017-6-30  13:51:16:646117985  ...          0.0888   0.871729
# 4      2017-6-30  13:51:16:846738994  ...          0.0359   1.048889
# ...          ...                 ...  ...             ...        ...
# 88583   2017-7-9   20:9:15:317911028  ...         -0.1327   0.902382
# 88584   2017-7-9   20:9:15:517889022  ...         -0.4397   1.202684
# 88585   2017-7-9   20:9:15:717828989  ...         -0.2827   1.295380
# 88586   2017-7-9   20:9:15:917932987  ...         -0.0759   0.899638
# 88587   2017-7-9   20:9:16:117410004  ...         -0.0911   0.864972
#
# [88588 rows x 7 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
pred= model.predict(X_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     17683
#            1       0.96      0.96      0.96     17753
#
#     accuracy                           0.96     35436
#    macro avg       0.96      0.96      0.96     35436
# weighted avg       0.96      0.96      0.96     35436

# %%
model.score(X_test,y_test)
# Out:
# 0.9582910034992663

# %%
X_test
# Out:
#        acceleration_x  acceleration_y  acceleration_z  total_acc
# 50230          0.5052          1.0871          0.2797   1.230953
# 11133         -2.3838         -0.3566         -0.3659   2.437939
# 4112          -0.1207         -1.1369         -0.2547   1.171316
# 76429          0.1851         -0.7972         -0.1917   0.840559
# 82774          2.6074         -0.1817         -1.4797   3.003508
# ...               ...             ...             ...        ...
# 61475         -0.2436         -0.4508          0.3599   0.626171
# 19511         -1.0817          0.1788          0.1496   1.106537
# 6409           0.0536         -0.8992         -0.3616   0.970664
# 27572         -0.1864         -1.1049         -0.4074   1.192277
# 82798         -0.2205          0.4429          0.1480   0.516415
#
# [35436 rows x 4 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
model =RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
pred= model.predict(X_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     17683
#            1       0.98      0.96      0.97     17753
#
#     accuracy                           0.97     35436
#    macro avg       0.97      0.97      0.97     35436
# weighted avg       0.97      0.97      0.97     35436

# %%
model.score(X_test,y_test)
# Out:
# 0.9733886443165143

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
k_val=KFold(10)

# %%
testdf=pd.read_csv("/content/drive/My Drive/running(1).txt",header=None)

# %%
testdf
# Out:
#       0    1    2    3   4
# 0   NaN -0.1  1.7  0.9 NaN
# 1   NaN -0.7  0.3  1.0 NaN
# 2   NaN  2.1  1.2  0.1 NaN
# 3   NaN  2.3  0.3 -0.5 NaN
# 4   NaN -0.1 -1.4 -1.2 NaN
# ..   ..  ...  ...  ...  ..
# 709 NaN  0.2 -0.2 -2.7 NaN
# 710 NaN  0.4  0.3 -0.3 NaN
# 711 NaN -0.3  0.0 -2.3 NaN
# 712 NaN  0.0  0.5 -0.8 NaN
# 713 NaN  0.2  0.3  0.2 NaN
#
# [714 rows x 5 columns]

# %%
testdf.drop([0,4],axis=1,inplace=True)
testdf
# Out:
#        1    2    3
# 0   -0.1  1.7  0.9
# 1   -0.7  0.3  1.0
# 2    2.1  1.2  0.1
# 3    2.3  0.3 -0.5
# 4   -0.1 -1.4 -1.2
# ..   ...  ...  ...
# 709  0.2 -0.2 -2.7
# 710  0.4  0.3 -0.3
# 711 -0.3  0.0 -2.3
# 712  0.0  0.5 -0.8
# 713  0.2  0.3  0.2
#
# [714 rows x 3 columns]

# %%
testdf['total_acc']=testdf[1]**2+testdf[2]**2+testdf[3]**2
testdf['activity']=1

# %%
testdf
# Out:
#        1    2    3  total_acc  activity
# 0   -0.1  1.7  0.9       3.71         1
# 1   -0.7  0.3  1.0       1.58         1
# 2    2.1  1.2  0.1       5.86         1
# 3    2.3  0.3 -0.5       5.63         1
# 4   -0.1 -1.4 -1.2       3.41         1
# ..   ...  ...  ...        ...       ...
# 709  0.2 -0.2 -2.7       7.37         1
# 710  0.4  0.3 -0.3       0.34         1
# 711 -0.3  0.0 -2.3       5.38         1
# 712  0.0  0.5 -0.8       0.89         1
# 713  0.2  0.3  0.2       0.17         1
#
# [714 rows x 5 columns]

# %%
pred= model.predict(testdf[[1,2,3,'total_acc']])

# %%
print(classification_report(testdf['activity'],pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      1.00      1.00       714
#
#     accuracy                           1.00       714
#    macro avg       0.50      0.50      0.50       714
# weighted avg       1.00      1.00      1.00       714
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model.score(testdf[[1,2,3,'activity']],testdf['activity'])
# Out:
# 0.9817927170868347

# %%
testdf[[1,2,3]]
# Out:
#        1    2    3
# 0   -0.1  1.7  0.9
# 1   -0.7  0.3  1.0
# 2    2.1  1.2  0.1
# 3    2.3  0.3 -0.5
# 4   -0.1 -1.4 -1.2
# ..   ...  ...  ...
# 709  0.2 -0.2 -2.7
# 710  0.4  0.3 -0.3
# 711 -0.3  0.0 -2.3
# 712  0.0  0.5 -0.8
# 713  0.2  0.3  0.2
#
# [714 rows x 3 columns]

# %%
res=cross_val_score(model,X,y,cv=k_val)

# %%
res
# Out:
# array([0.9685066 , 0.98295519, 0.99130827, 0.98284231, 0.99040524,
#        0.96252399, 0.96715205, 0.94909132, 0.94942425, 0.93576428])

# %%
np.mean(res)
# Out:
# 0.9679973494585183

# %%
import joblib

# %%
file="model_finale.sav"

# %%
joblib.dump(model,file)
# Out:
# ['model_finale.sav']

# %%
cls=joblib.load('model_finale.sav')

# %%
d=testdf.to_numpy()

# %%
d
# Out:
# array([[-0.1 ,  1.7 ,  0.9 ,  3.71,  1.  ],
#        [-0.7 ,  0.3 ,  1.  ,  1.58,  1.  ],
#        [ 2.1 ,  1.2 ,  0.1 ,  5.86,  1.  ],
#        ...,
#        [-0.3 ,  0.  , -2.3 ,  5.38,  1.  ],
#        [ 0.  ,  0.5 , -0.8 ,  0.89,  1.  ],
#        [ 0.2 ,  0.3 ,  0.2 ,  0.17,  1.  ]])

# %%
d[:,:4]
# Out:
# array([[-0.1 ,  1.7 ,  0.9 ,  3.71],
#        [-0.7 ,  0.3 ,  1.  ,  1.58],
#        [ 2.1 ,  1.2 ,  0.1 ,  5.86],
#        ...,
#        [-0.3 ,  0.  , -2.3 ,  5.38],
#        [ 0.  ,  0.5 , -0.8 ,  0.89],
#        [ 0.2 ,  0.3 ,  0.2 ,  0.17]])

# %%
x=cls.predict(d[:,:4])

# %%
x=list(x)

# %%
x.count(1)
# Out:
# 713

# %%
x.count(0)
# Out:
# 1

# %%
p=(x.count(1)/len(x))

# %%
((20*len(x))/1000)*p
# Out:
# 14.26
